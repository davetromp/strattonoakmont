# %%
# %matplotlib inline

# %%
import sys
import numpy as np
from bittrex import bittrex
import pandas as pd
import matplotlib.pyplot as plt
from secret import *
from performance import getPerformance

# %%
getPerformance('BTC-MCO')
# Out:
# Difference between average sells and buys
# 0.00755621510679

# %%
getPerformance('BTC-NEO')
# Out:
# Difference between average sells and buys
# -0.00379782261801

# %%
getPerformance('BTC-APX')
# Out:
# Difference between average sells and buys
# 0.00131852736842
